# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
## Define the vocabulary size
voc_size=10000

# %%
### One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[4533, 9929, 3862, 6610],
#  [4533, 9929, 3862, 6],
#  [4533, 2432, 3862, 8623],
#  [1887, 3089, 3801, 762, 6920],
#  [1887, 3089, 3801, 762, 504],
#  [8333, 4533, 7878, 3862, 8937],
#  [6425, 2813, 8791, 762]]

# %%
## word Embedding Representation

from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 4533 9929 3862 6610]
#  [   0    0    0    0 4533 9929 3862    6]
#  [   0    0    0    0 4533 2432 3862 8623]
#  [   0    0    0 1887 3089 3801  762 6920]
#  [   0    0    0 1887 3089 3801  762  504]
#  [   0    0    0 8333 4533 7878 3862 8937]
#  [   0    0    0    0 6425 2813 8791  762]]

# %%
## feature representation
dim=10

# %%
## Create model

model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# d:\Deep_Learning_NLP\venv\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# array([[[ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.03586331, -0.02878095,  0.04245063,  0.01205369,
#          -0.04837693,  0.02763165, -0.0485167 ,  0.04273145,
#           0.03451593, -0.02384461],
#         [-0.0438249 ,  0.0189183 ,  0.03055588, -0.04129688,
#          -0.01312586, -0.01074366, -0.00622372,  0.03059999,
#          -0.0376383 , -0.02771345],
#         [ 0.02472024, -0.02241823,  0.01918044, -0.00785876,
#           0.01405131,  0.01448179, -0.04424512, -0.02403721,
#          -0.04173825, -0.03095119],
#         [-0.043537  , -0.02995282, -0.02005038,  0.0336342 ,
#          -0.03801758, -0.00500067, -0.04039961,  0.01785779,
#           0.00614897, -0.02028604]],
#
#        [[ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.03586331, -0.02878095,  0.04245063,  0.01205369,
#          -0.04837693,  0.02763165, -0.0485167 ,  0.04273145,
#           0.03451593, -0.02384461],
#         [-0.0438249 ,  0.0189183 ,  0.03055588, -0.04129688,
#          -0.01312586, -0.01074366, -0.00622372,  0.03059999,
#          -0.0376383 , -0.02771345],
#         [ 0.02472024, -0.02241823,  0.01918044, -0.00785876,
#           0.01405131,  0.01448179, -0.04424512, -0.02403721,
#          -0.04173825, -0.03095119],
#         [-0.0269434 ,  0.03673897, -0.00564698,  0.01364816,
#           0.02644949, -0.02269621, -0.04594069,  0.01784119,
#          -0.02529728, -0.0168244 ]],
#
#        [[ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.03586331, -0.02878095,  0.04245063,  0.01205369,
#          -0.04837693,  0.02763165, -0.0485167 ,  0.04273145,
#           0.03451593, -0.02384461],
#         [ 0.02271925, -0.01059692, -0.0045181 , -0.0018758 ,
#           0.02565284,  0.02620869,  0.01547701, -0.0277036 ,
#           0.04648454, -0.01682272],
#         [ 0.02472024, -0.02241823,  0.01918044, -0.00785876,
#           0.01405131,  0.01448179, -0.04424512, -0.02403721,
#          -0.04173825, -0.03095119],
#         [ 0.04603093,  0.02632418,  0.00909621, -0.04311487,
#          -0.02763996,  0.04395732,  0.03429282,  0.0286123 ,
#          -0.01824483, -0.02200159]],
#
#        [[ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04112503, -0.03692422,  0.02614578,  0.02136563,
#          -0.00408429,  0.03396333,  0.04252252, -0.04629756,
#          -0.04481158, -0.02512058],
#         [ 0.03384285, -0.03132768, -0.01567377, -0.02292922,
#           0.01950762, -0.03718237, -0.02928284,  0.03382732,
#          -0.03548827, -0.03240317],
#         [-0.03966532,  0.00564027, -0.007852  , -0.02402024,
#          -0.02415198, -0.02771184, -0.00444946, -0.00411516,
#           0.00119447,  0.03098922],
#         [ 0.02003422, -0.00241463, -0.03723676,  0.00926148,
#           0.04265029, -0.00229708, -0.02396815, -0.02230722,
#           0.04492599, -0.03936657],
#         [-0.01191316,  0.00924314,  0.04901804,  0.0441378 ,
#           0.03779343, -0.03473263,  0.04243708,  0.0059128 ,
#          -0.03685707, -0.04003549]],
#
#        [[ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04112503, -0.03692422,  0.02614578,  0.02136563,
#          -0.00408429,  0.03396333,  0.04252252, -0.04629756,
#          -0.04481158, -0.02512058],
#         [ 0.03384285, -0.03132768, -0.01567377, -0.02292922,
#           0.01950762, -0.03718237, -0.02928284,  0.03382732,
#          -0.03548827, -0.03240317],
#         [-0.03966532,  0.00564027, -0.007852  , -0.02402024,
#          -0.02415198, -0.02771184, -0.00444946, -0.00411516,
#           0.00119447,  0.03098922],
#         [ 0.02003422, -0.00241463, -0.03723676,  0.00926148,
#           0.04265029, -0.00229708, -0.02396815, -0.02230722,
#           0.04492599, -0.03936657],
#         [-0.02327027, -0.00739052,  0.01806152,  0.04541557,
#          -0.04387611,  0.04758309,  0.03349794,  0.02335757,
#          -0.02256758,  0.01607228]],
#
#        [[ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.00605993,  0.01550014,  0.00263191, -0.0060033 ,
#           0.03642765,  0.00731323, -0.04517322,  0.01723737,
#          -0.01618805,  0.03295559],
#         [ 0.03586331, -0.02878095,  0.04245063,  0.01205369,
#          -0.04837693,  0.02763165, -0.0485167 ,  0.04273145,
#           0.03451593, -0.02384461],
#         [ 0.01846044, -0.04282141,  0.01322422, -0.02475376,
#          -0.00379256,  0.01419543,  0.01783513, -0.02349043,
#           0.01948306, -0.04703615],
#         [ 0.02472024, -0.02241823,  0.01918044, -0.00785876,
#           0.01405131,  0.01448179, -0.04424512, -0.02403721,
#          -0.04173825, -0.03095119],
#         [ 0.00606222,  0.02054207,  0.00531811, -0.00544737,
#          -0.04995321,  0.02073475, -0.01610328,  0.02451669,
#           0.02537381,  0.04339748]],
#
#        [[ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [-0.02164519,  0.03991199, -0.02391336, -0.01960543,
#          -0.0229086 ,  0.0094535 ,  0.02723085, -0.02756186,
#          -0.01218089, -0.00050194],
#         [ 0.02961631,  0.0051599 , -0.01789797,  0.03352605,
#          -0.04686031, -0.03326365, -0.00763161,  0.00928098,
#          -0.01942088,  0.01065643],
#         [ 0.02070205,  0.04804141,  0.0442338 ,  0.01932354,
#          -0.02462378, -0.0032509 , -0.0077926 ,  0.02860809,
#           0.03366016,  0.00647116],
#         [ 0.02003422, -0.00241463, -0.03723676,  0.00926148,
#           0.04265029, -0.00229708, -0.02396815, -0.02230722,
#           0.04492599, -0.03936657]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 4533, 9929, 3862, 6610], dtype=int32)

# %%
embedded_docs[0:1]
# Out:
# array([[   0,    0,    0,    0, 4533, 9929, 3862, 6610]], dtype=int32)

# %%
model.predict(embedded_docs[0:1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# array([[[ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.04745313, -0.04713256,  0.04794231,  0.04500966,
#          -0.04107643, -0.04426451,  0.03090488,  0.03239429,
#          -0.03298482,  0.02764976],
#         [ 0.03586331, -0.02878095,  0.04245063,  0.01205369,
#          -0.04837693,  0.02763165, -0.0485167 ,  0.04273145,
#           0.03451593, -0.02384461],
#         [-0.0438249 ,  0.0189183 ,  0.03055588, -0.04129688,
#          -0.01312586, -0.01074366, -0.00622372,  0.03059999,
#          -0.0376383 , -0.02771345],
#         [ 0.02472024, -0.02241823,  0.01918044, -0.00785876,
#           0.01405131,  0.01448179, -0.04424512, -0.02403721,
#          -0.04173825, -0.03095119],
#         [-0.043537  , -0.02995282, -0.02005038,  0.0336342 ,
#          -0.03801758, -0.00500067, -0.04039961,  0.01785779,
#           0.00614897, -0.02028604]]], dtype=float32)
